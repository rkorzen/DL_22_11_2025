# %% [markdown]
# # Ćwiczenia z podstaw PyTorcha
# W tych zadaniach utworzymy tensor i wykonamy na nim kilka operacji.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>WAŻNA UWAGA!</strong> Nie uruchamiaj komórek znajdujących się bezpośrednio nad przykładowymi wynikami,<br>w przeciwnym razie nadpiszesz pokazane rozwiązania!</div>

# %% [markdown]
# ### 1. Wykonaj standardowe importy
# Zaimportuj torch oraz NumPy.

# %%
# KOD TUTAJ
# !pip install tensorflow==2.16.2
# Out:
# Collecting tensorflow==2.16.2
#   Downloading tensorflow-2.16.2-cp311-cp311-macosx_10_15_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.16.2)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.16.2)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow==2.16.2)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow==2.16.2)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.16.2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.2)
#   Downloading h5py-3.15.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.0 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.2)
#   Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.16.2)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2)
#   Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (2.32.5)
# Requirement already satisfied: setuptools in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.16.2)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (2.0.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.16.2)
#   Downloading grpcio-1.76.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.2)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.16.2)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_10_14_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2025.11.12)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.16.2)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (14.2.0)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading optree-0.18.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/rkorzen/workspace/szkolenia/DL_22_11_2025/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2) (0.1.2)
# Downloading tensorflow-2.16.2-cp311-cp311-macosx_10_15_x86_64.whl (259.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.6/259.6 MB 9.8 MB/s  0:00:26s eta 0:00:010:00:01
# Downloading grpcio-1.76.0-cp311-cp311-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 11.1 MB/s  0:00:01 eta 0:00:0136m0:00:01
# Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
# Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.0 MB/s  0:00:009.5 MB/s eta 0:00:01:01
# Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 10.0 MB/s  0:00:001.3 MB/s eta 0:00:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp311-cp311-macosx_10_9_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 10.1 MB/s  0:00:001.7 MB/s eta 0:00:01
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.0 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 10.8 MB/s  0:00:020.9 MB/s eta 0:00:01:01
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_10_14_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 9.9 MB/s  0:00:0012.2 MB/s eta 0:00:01
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.18.0-cp311-cp311-macosx_10_9_x86_64.whl (363 kB)
# Installing collected packages: namex, libclang, flatbuffers, wheel, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, markdown, h5py, grpcio, google-pasta, gast, absl-py, tensorboard, astunparse, keras, tensorflow
#   Attempting uninstall: protobuf0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/22 [termcolor]clang]
#     Found existing installation: protobuf 6.33.138;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/22 [termcolor]
#     Uninstalling protobuf-6.33.1:8;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/22 [termcolor]
#       Successfully uninstalled protobuf-6.33.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/22 [termcolor]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [tensorflow]0m 21/22 [tensorflow]orboard]
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.6.0 google-pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 libclang-18.1.1 markdown-3.10 ml-dtypes-0.3.2 namex-0.1.0 opt-einsum-3.4.0 optree-0.18.0 protobuf-4.25.8 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.2.0 werkzeug-3.1.3 wheel-0.45.1

# %% [markdown]
# ### 2. Ustaw ziarno losowe NumPy i PyTorch na wartość „42”
# Dzięki temu będziemy otrzymywać te same „losowe” wyniki.

# %%
# KOD TUTAJ

# %% [markdown]
# ### 3. Utwórz tablicę NumPy „arr” zawierającą 6 losowych liczb całkowitych z zakresu [0, 5)

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# [3 4 2 4 4 1]

# %% [markdown]
# ### 4. Utwórz tensor „x” z powyższej tablicy

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([3, 4, 2, 4, 4, 1], dtype=torch.int32)

# %% [markdown]
# ### 5. Zmień dtype tensora x z 'int32' na 'int64'
# Uwaga: 'int64' to również 'LongTensor'.

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# torch.LongTensor

# %% [markdown]
# ### 6. Przekształć x do tensora 3x2
# Można to zrobić na kilka sposobów.

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([[3, 4],
#         [2, 4],
#         [4, 1]])

# %% [markdown]
# ### 7. Zwróć prawą kolumnę tensora x

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([[4],
#         [4],
#         [1]])

# %% [markdown]
# ### 8. Nie zmieniając x, zwróć tensor z kwadratami jego wartości
# Można to zrobić na kilka sposobów.

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([[ 9, 16],
#         [ 4, 16],
#         [16,  1]])

# %% [markdown]
# ### 9. Utwórz tensor „y” z taką samą liczbą elementów jak x, umożliwiający mnożenie macierzy z x
# Użyj bezpośrednio PyTorcha (nie NumPy), aby stworzyć tensor losowych liczb całkowitych z zakresu [0, 5).<br>
# Zastanów się, jaki kształt musi mieć tensor, aby mnożenie macierzy było możliwe.

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([[2, 2, 1],
#         [4, 1, 0]])

# %% [markdown]
# ### 10. Znajdź iloczyn macierzowy tensorów x i y

# %%
# KOD TUTAJ

# %%
# NIE PISZ TUTAJ
# Out:
# tensor([[22, 10,  3],
#         [20,  8,  2],
#         [12,  9,  4]])

# %% [markdown]
# ## Świetna robota!
