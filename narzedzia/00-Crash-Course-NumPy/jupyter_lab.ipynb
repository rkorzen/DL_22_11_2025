# %%
# pip install jupyterlab
# jupyter lab

# %% [markdown]
# # poruszanie sie
#
# esc potem strzalki
#
# ## edycja: Enter
#
# ## wykonanie komorki
#
# shift + Enter
#
# ctrl + Enter
#
# alt + Enter
#
# ## zmiania typu komorki
#
# * esc - przejscie w tryb polecen
#
# * y - komorka code
# *    m - komorkla markdown
#
# ## Dodawanie, usuwanie komorek
#
# w trybie polecen
#
# * a - dodanie wyzej
# * b - ponizej
# * dd - usuniecie komorki

# %%
x = 1
