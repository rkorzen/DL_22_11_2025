# %%
import tensorflow as tf
import numpy as np

model_name = 'model.keras'
loaded_model = tf.keras.models.load_model(model_name)


# Dane testowe
x_test = np.array([[-0.5], [0.0], [0.5]])
predictions = loaded_model.predict(x_test)

print('Predykcje (SavedModel):', predictions.flatten())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predykcje (SavedModel): [0.47628438 1.9888366  3.501389  ]

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'loaded_model',
#  'model_name',
#  'np',
#  'open',
#  'predictions',
#  'quit',
#  'tf',
#  'x_test']
